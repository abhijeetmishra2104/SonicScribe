# %%
import pandas as pd 
import numpy as np

# %%
test = pd.read_csv(r'C:\Users\vaimi\OneDrive\Desktop\SonicScribe\ai-model\Dataset\train_cyf.csv')

# %%
test.head()
# Out:
#    age  gender primary_diagnosis  num_procedures  days_in_hospital  \
# 0   69    Male     Heart Disease               1                 2
# 1   32  Female              COPD               2                13
# 2   89    Male          Diabetes               1                 7
# 3   78    Male              COPD               9                 2
# 4   38    Male          Diabetes               6                 4
#
#    comorbidity_score              discharge_to  readmitted
# 0                  1          Home Health Care           0
# 1                  2   Rehabilitation Facility           0
# 2                  1                      Home           0
# 3                  2  Skilled Nursing Facility           0
# 4                  4   Rehabilitation Facility           0

# %%
train=pd.read_csv(r'C:\Users\vaimi\OneDrive\Desktop\SonicScribe\ai-model\Dataset\train_cyf.csv')

# %%
train.head()
# Out:
#    age  gender primary_diagnosis  num_procedures  days_in_hospital  \
# 0   69    Male     Heart Disease               1                 2
# 1   32  Female              COPD               2                13
# 2   89    Male          Diabetes               1                 7
# 3   78    Male              COPD               9                 2
# 4   38    Male          Diabetes               6                 4
#
#    comorbidity_score              discharge_to  readmitted
# 0                  1          Home Health Care           0
# 1                  2   Rehabilitation Facility           0
# 2                  1                      Home           0
# 3                  2  Skilled Nursing Facility           0
# 4                  4   Rehabilitation Facility           0

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Categorical data -> numerical data  (using LabelEncoding)

categorical_cols = ['gender', 'primary_diagnosis', 'discharge_to']
label_encoders = {}

for col in categorical_cols:
    encoder = LabelEncoder()
    train[col] = encoder.fit_transform(train[col])
    test[col] = encoder.transform(test[col])
    label_encoders[col] = encoder

# %%
X_train=train.drop(columns="readmitted")
y_train=train["readmitted"]
X_test=test.drop(columns="readmitted")
y_test=test["readmitted"]

# %%
print(y_train.shape)
# Out:
# (5000,)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score

# %%
print(y_train.dtypes)
# Out:
# int64

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predictions (0 or 1)
y_pred = model.predict(X_test)

# Risk scores (probability of readmission)
y_proba = model.predict_proba(X_test)[:, 1]  # Probability of class 1 (readmitted)

# %%
from sklearn.metrics import roc_auc_score, classification_report

print("ROC-AUC Score:", roc_auc_score(y_test, y_proba))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# ROC-AUC Score: 0.9999998689864794
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      4060
#            1       1.00      1.00      1.00       940
#
#     accuracy                           1.00      5000
#    macro avg       1.00      1.00      1.00      5000
# weighted avg       1.00      1.00      1.00      5000

# %%
for i in range(len(X_test)):
    risk = y_proba[i] * 100  # percentage
    decision = "Admit" if risk > 70 else "No Need to Admit"
    print(f"Patient {i+1}: Risk = {risk:.2f}% -> {decision}")
# Out:
# Patient 1: Risk = 5.00% -> No Need to Admit
# Patient 2: Risk = 4.00% -> No Need to Admit
# Patient 3: Risk = 7.00% -> No Need to Admit
# Patient 4: Risk = 10.00% -> No Need to Admit
# Patient 5: Risk = 11.00% -> No Need to Admit
# Patient 6: Risk = 1.00% -> No Need to Admit
# Patient 7: Risk = 13.00% -> No Need to Admit
# Patient 8: Risk = 6.00% -> No Need to Admit
# Patient 9: Risk = 17.00% -> No Need to Admit
# Patient 10: Risk = 6.00% -> No Need to Admit
# Patient 11: Risk = 4.00% -> No Need to Admit
# Patient 12: Risk = 27.00% -> No Need to Admit
# Patient 13: Risk = 13.00% -> No Need to Admit
# Patient 14: Risk = 8.00% -> No Need to Admit
# Patient 15: Risk = 16.00% -> No Need to Admit
# Patient 16: Risk = 10.00% -> No Need to Admit
# Patient 17: Risk = 18.00% -> No Need to Admit
# Patient 18: Risk = 7.00% -> No Need to Admit
# Patient 19: Risk = 9.00% -> No Need to Admit
# Patient 20: Risk = 73.00% -> Admit
# Patient 21: Risk = 78.00% -> Admit
# Patient 22: Risk = 8.00% -> No Need to Admit
# Patient 23: Risk = 70.00% -> No Need to Admit
# Patient 24: Risk = 1.00% -> No Need to Admit
# Patient 25: Risk = 5.00% -> No Need to Admit
# Patient 26: Risk = 3.00% -> No Need to Admit
# Patient 27: Risk = 11.00% -> No Need to Admit
# Patient 28: Risk = 8.00% -> No Need to Admit
# Patient 29: Risk = 8.00% -> No Need to Admit
# Patient 30: Risk = 13.00% -> No Need to Admit
# Patient 31: Risk = 3.00% -> No Need to Admit
# Patient 32: Risk = 6.00% -> No Need to Admit
# Patient 33: Risk = 5.00% -> No Need to Admit
# Patient 34: Risk = 10.00% -> No Need to Admit
# Patient 35: Risk = 0.00% -> No Need to Admit
# Patient 36: Risk = 10.00% -> No Need to Admit
# Patient 37: Risk = 9.00% -> No Need to Admit
# Patient 38: Risk = 8.00% -> No Need to Admit
# Patient 39: Risk = 11.00% -> No Need to Admit
# Patient 40: Risk = 11.00% -> No Need to Admit
# Patient 41: Risk = 2.00% -> No Need to Admit
# Patient 42: Risk = 7.00% -> No Need to Admit
# Patient 43: Risk = 7.00% -> No Need to Admit
# Patient 44: Risk = 11.00% -> No Need to Admit
# Patient 45: Risk = 8.00% -> No Need to Admit
# Patient 46: Risk = 70.00% -> No Need to Admit
# Patient 47: Risk = 9.00% -> No Need to Admit
# Patient 48: Risk = 6.00% -> No Need to Admit
# Patient 49: Risk = 11.00% -> No Need to Admit
# Patient 50: Risk = 2.00% -> No Need to Admit
# Patient 51: Risk = 10.00% -> No Need to Admit
# Patient 52: Risk = 10.00% -> No Need to Admit
# Patient 53: Risk = 5.00% -> No Need to Admit
# Patient 54: Risk = 14.00% -> No Need to Admit
# Patient 55: Risk = 2.00% -> No Need to Admit
# Patient 56: Risk = 12.00% -> No Need to Admit
# Patient 57: Risk = 14.00% -> No Need to Admit
# Patient 58: Risk = 5.00% -> No Need to Admit
# Patient 59: Risk = 9.00% -> No Need to Admit
# Patient 60: Risk = 6.00% -> No Need to Admit
# Patient 61: Risk = 3.00% -> No Need to Admit
# Patient 62: Risk = 7.00% -> No Need to Admit
# Patient 63: Risk = 5.00% -> No Need to Admit
# Patient 64: Risk = 4.00% -> No Need to Admit
# Patient 65: Risk = 9.00% -> No Need to Admit
# Patient 66: Risk = 3.00% -> No Need to Admit
# Patient 67: Risk = 73.00% -> Admit
# Patient 68: Risk = 7.00% -> No Need to Admit
# Patient 69: Risk = 9.00% -> No Need to Admit
# Patient 70: Risk = 5.00% -> No Need to Admit
# Patient 71: Risk = 6.00% -> No Need to Admit
# Patient 72: Risk = 5.00% -> No Need to Admit
# Patient 73: Risk = 8.00% -> No Need to Admit
# Patient 74: Risk = 10.00% -> No Need to Admit
# Patient 75: Risk = 8.00% -> No Need to Admit
# Patient 76: Risk = 73.00% -> Admit
# Patient 77: Risk = 4.00% -> No Need to Admit
# Patient 78: Risk = 3.00% -> No Need to Admit
# Patient 79: Risk = 4.00% -> No Need to Admit
# Patient 80: Risk = 5.00% -> No Need to Admit
# Patient 81: Risk = 73.00% -> Admit
# Patient 82: Risk = 6.00% -> No Need to Admit
# Patient 83: Risk = 70.00% -> No Need to Admit
# Patient 84: Risk = 6.00% -> No Need to Admit
# Patient 85: Risk = 4.00% -> No Need to Admit
# Patient 86: Risk = 4.00% -> No Need to Admit
# Patient 87: Risk = 3.00% -> No Need to Admit
# Patient 88: Risk = 12.00% -> No Need to Admit
# Patient 89: Risk = 5.00% -> No Need to Admit
# Patient 90: Risk = 2.00% -> No Need to Admit
# Patient 91: Risk = 68.00% -> No Need to Admit
# Patient 92: Risk = 8.00% -> No Need to Admit
# Patient 93: Risk = 7.00% -> No Need to Admit
# Patient 94: Risk = 4.00% -> No Need to Admit
# Patient 95: Risk = 40.32% -> No Need to Admit
# Patient 96: Risk = 1.00% -> No Need to Admit
# Patient 97: Risk = 7.00% -> No Need to Admit
# Patient 98: Risk = 4.00% -> No Need to Admit
# Patient 99: Risk = 6.00% -> No Need to Admit
# Patient 100: Risk = 12.00% -> No Need to Admit
# Patient 101: Risk = 5.00% -> No Need to Admit
# Patient 102: Risk = 61.00% -> No Need to Admit
# Patient 103: Risk = 14.00% -> No Need to Admit
# Patient 104: Risk = 12.00% -> No Need to Admit
# Patient 105: Risk = 11.00% -> No Need to Admit
# Patient 106: Risk = 8.00% -> No Need to Admit
# Patient 107: Risk = 6.00% -> No Need to Admit
# Patient 108: Risk = 71.00% -> Admit
# Patient 109: Risk = 73.00% -> Admit
# Patient 110: Risk = 67.00% -> No Need to Admit
# Patient 111: Risk = 66.00% -> No Need to Admit
# Patient 112: Risk = 9.00% -> No Need to Admit
# Patient 113: Risk = 7.00% -> No Need to Admit
# Patient 114: Risk = 5.00% -> No Need to Admit
# Patient 115: Risk = 8.00% -> No Need to Admit
# Patient 116: Risk = 5.00% -> No Need to Admit
# Patient 117: Risk = 5.00% -> No Need to Admit
# Patient 118: Risk = 10.00% -> No Need to Admit
# Patient 119: Risk = 3.00% -> No Need to Admit
# Patient 120: Risk = 63.00% -> No Need to Admit
# Patient 121: Risk = 68.00% -> No Need to Admit
# Patient 122: Risk = 10.00% -> No Need to Admit
# Patient 123: Risk = 16.00% -> No Need to Admit
# Patient 124: Risk = 74.00% -> Admit
# Patient 125: Risk = 63.00% -> No Need to Admit
# Patient 126: Risk = 69.00% -> No Need to Admit
# Patient 127: Risk = 81.00% -> Admit
# Patient 128: Risk = 79.00% -> Admit
# Patient 129: Risk = 2.00% -> No Need to Admit
# Patient 130: Risk = 9.00% -> No Need to Admit
# Patient 131: Risk = 8.00% -> No Need to Admit
# Patient 132: Risk = 6.00% -> No Need to Admit
# Patient 133: Risk = 65.00% -> No Need to Admit
# Patient 134: Risk = 0.00% -> No Need to Admit
# Patient 135: Risk = 6.00% -> No Need to Admit
# Patient 136: Risk = 2.00% -> No Need to Admit
# Patient 137: Risk = 11.00% -> No Need to Admit
# Patient 138: Risk = 4.00% -> No Need to Admit
# Patient 139: Risk = 78.00% -> Admit
# Patient 140: Risk = 10.00% -> No Need to Admit
# Patient 141: Risk = 67.00% -> No Need to Admit
# Patient 142: Risk = 74.00% -> Admit
# Patient 143: Risk = 1.00% -> No Need to Admit
# Patient 144: Risk = 2.00% -> No Need to Admit
# Patient 145: Risk = 5.00% -> No Need to Admit
# Patient 146: Risk = 5.00% -> No Need to Admit
# Patient 147: Risk = 7.00% -> No Need to Admit
# Patient 148: Risk = 76.00% -> Admit
# Patient 149: Risk = 13.00% -> No Need to Admit
# Patient 150: Risk = 11.00% -> No Need to Admit
# Patient 151: Risk = 15.00% -> No Need to Admit
# Patient 152: Risk = 1.00% -> No Need to Admit
# Patient 153: Risk = 7.00% -> No Need to Admit
# Patient 154: Risk = 15.00% -> No Need to Admit
# Patient 155: Risk = 9.00% -> No Need to Admit
# Patient 156: Risk = 5.00% -> No Need to Admit
# Patient 157: Risk = 8.00% -> No Need to Admit
# Patient 158: Risk = 6.00% -> No Need to Admit
# Patient 159: Risk = 4.00% -> No Need to Admit
# Patient 160: Risk = 6.00% -> No Need to Admit
# Patient 161: Risk = 9.00% -> No Need to Admit
# Patient 162: Risk = 2.00% -> No Need to Admit
# Patient 163: Risk = 4.00% -> No Need to Admit
# Patient 164: Risk = 7.00% -> No Need to Admit
# Patient 165: Risk = 5.00% -> No Need to Admit
# Patient 166: Risk = 69.00% -> No Need to Admit
# Patient 167: Risk = 6.00% -> No Need to Admit
# Patient 168: Risk = 14.00% -> No Need to Admit
# Patient 169: Risk = 5.00% -> No Need to Admit
# Patient 170: Risk = 8.00% -> No Need to Admit
# Patient 171: Risk = 2.00% -> No Need to Admit
# Patient 172: Risk = 13.00% -> No Need to Admit
# Patient 173: Risk = 10.00% -> No Need to Admit
# Patient 174: Risk = 10.00% -> No Need to Admit
# Patient 175: Risk = 11.00% -> No Need to Admit
# Patient 176: Risk = 7.00% -> No Need to Admit
# Patient 177: Risk = 10.00% -> No Need to Admit
# Patient 178: Risk = 4.00% -> No Need to Admit
# Patient 179: Risk = 2.00% -> No Need to Admit
# Patient 180: Risk = 11.00% -> No Need to Admit
# Patient 181: Risk = 13.00% -> No Need to Admit
# Patient 182: Risk = 6.00% -> No Need to Admit
# Patient 183: Risk = 5.00% -> No Need to Admit
# Patient 184: Risk = 5.00% -> No Need to Admit
# Patient 185: Risk = 15.00% -> No Need to Admit
# Patient 186: Risk = 9.00% -> No Need to Admit
# Patient 187: Risk = 7.00% -> No Need to Admit
# Patient 188: Risk = 7.00% -> No Need to Admit
# Patient 189: Risk = 2.00% -> No Need to Admit
# Patient 190: Risk = 8.00% -> No Need to Admit
# Patient 191: Risk = 4.00% -> No Need to Admit
# Patient 192: Risk = 75.00% -> Admit
# Patient 193: Risk = 78.00% -> Admit
# Patient 194: Risk = 11.00% -> No Need to Admit
# Patient 195: Risk = 76.00% -> Admit
# Patient 196: Risk = 2.00% -> No Need to Admit
# Patient 197: Risk = 9.00% -> No Need to Admit
# Patient 198: Risk = 72.00% -> Admit
# Patient 199: Risk = 4.00% -> No Need to Admit
# Patient 200: Risk = 7.00% -> No Need to Admit
# Patient 201: Risk = 78.00% -> Admit
# Patient 202: Risk = 8.00% -> No Need to Admit
# Patient 203: Risk = 5.00% -> No Need to Admit
# Patient 204: Risk = 6.00% -> No Need to Admit
# Patient 205: Risk = 73.00% -> Admit
# Patient 206: Risk = 82.00% -> Admit
# Patient 207: Risk = 17.00% -> No Need to Admit
# Patient 208: Risk = 63.00% -> No Need to Admit
# Patient 209: Risk = 9.00% -> No Need to Admit
# Patient 210: Risk = 70.00% -> No Need to Admit
# Patient 211: Risk = 9.00% -> No Need to Admit
# Patient 212: Risk = 10.00% -> No Need to Admit
# Patient 213: Risk = 7.00% -> No Need to Admit
# Patient 214: Risk = 5.00% -> No Need to Admit
# Patient 215: Risk = 4.00% -> No Need to Admit
# Patient 216: Risk = 8.00% -> No Need to Admit
# Patient 217: Risk = 3.00% -> No Need to Admit
# Patient 218: Risk = 66.00% -> No Need to Admit
# Patient 219: Risk = 7.00% -> No Need to Admit
# Patient 220: Risk = 12.00% -> No Need to Admit
# Patient 221: Risk = 4.00% -> No Need to Admit
# Patient 222: Risk = 70.00% -> No Need to Admit
# Patient 223: Risk = 2.00% -> No Need to Admit
# Patient 224: Risk = 64.00% -> No Need to Admit
# Patient 225: Risk = 76.00% -> Admit
# Patient 226: Risk = 3.00% -> No Need to Admit
# Patient 227: Risk = 5.00% -> No Need to Admit
# Patient 228: Risk = 72.00% -> Admit
# Patient 229: Risk = 72.00% -> Admit
# Patient 230: Risk = 7.00% -> No Need to Admit
# Patient 231: Risk = 15.00% -> No Need to Admit
# Patient 232: Risk = 3.00% -> No Need to Admit
# Patient 233: Risk = 8.00% -> No Need to Admit
# Patient 234: Risk = 9.00% -> No Need to Admit
# Patient 235: Risk = 3.00% -> No Need to Admit
# Patient 236: Risk = 6.00% -> No Need to Admit
# Patient 237: Risk = 4.00% -> No Need to Admit
# Patient 238: Risk = 68.00% -> No Need to Admit
# Patient 239: Risk = 76.00% -> Admit
# Patient 240: Risk = 72.00% -> Admit
# Patient 241: Risk = 65.00% -> No Need to Admit
# Patient 242: Risk = 4.00% -> No Need to Admit
# Patient 243: Risk = 74.00% -> Admit
# Patient 244: Risk = 74.00% -> Admit
# Patient 245: Risk = 67.00% -> No Need to Admit
# Patient 246: Risk = 6.00% -> No Need to Admit
# Patient 247: Risk = 3.00% -> No Need to Admit
# Patient 248: Risk = 15.00% -> No Need to Admit
# Patient 249: Risk = 2.00% -> No Need to Admit
# Patient 250: Risk = 81.00% -> Admit
# Patient 251: Risk = 5.00% -> No Need to Admit
# Patient 252: Risk = 81.00% -> Admit
# Patient 253: Risk = 11.00% -> No Need to Admit
# Patient 254: Risk = 6.00% -> No Need to Admit
# Patient 255: Risk = 19.00% -> No Need to Admit
# Patient 256: Risk = 16.00% -> No Need to Admit
# Patient 257: Risk = 2.00% -> No Need to Admit
# Patient 258: Risk = 11.00% -> No Need to Admit
# Patient 259: Risk = 6.00% -> No Need to Admit
# Patient 260: Risk = 8.00% -> No Need to Admit
# Patient 261: Risk = 14.00% -> No Need to Admit
# Patient 262: Risk = 67.00% -> No Need to Admit
# Patient 263: Risk = 14.00% -> No Need to Admit
# Patient 264: Risk = 15.00% -> No Need to Admit
# Patient 265: Risk = 8.00% -> No Need to Admit
# Patient 266: Risk = 9.00% -> No Need to Admit
# Patient 267: Risk = 13.00% -> No Need to Admit
# Patient 268: Risk = 4.00% -> No Need to Admit
# Patient 269: Risk = 76.00% -> Admit
# Patient 270: Risk = 9.00% -> No Need to Admit
# Patient 271: Risk = 1.00% -> No Need to Admit
# Patient 272: Risk = 8.00% -> No Need to Admit
# Patient 273: Risk = 12.00% -> No Need to Admit
# Patient 274: Risk = 3.00% -> No Need to Admit
# Patient 275: Risk = 10.00% -> No Need to Admit
# Patient 276: Risk = 10.00% -> No Need to Admit
# Patient 277: Risk = 10.00% -> No Need to Admit
# Patient 278: Risk = 4.00% -> No Need to Admit
# Patient 279: Risk = 72.00% -> Admit
# Patient 280: Risk = 3.00% -> No Need to Admit
# Patient 281: Risk = 8.00% -> No Need to Admit
# Patient 282: Risk = 70.00% -> No Need to Admit
# Patient 283: Risk = 9.00% -> No Need to Admit
# Patient 284: Risk = 8.00% -> No Need to Admit
# Patient 285: Risk = 74.00% -> Admit
# Patient 286: Risk = 18.00% -> No Need to Admit
# Patient 287: Risk = 20.00% -> No Need to Admit
# Patient 288: Risk = 63.00% -> No Need to Admit
# Patient 289: Risk = 71.00% -> Admit
# Patient 290: Risk = 7.00% -> No Need to Admit
# Patient 291: Risk = 10.00% -> No Need to Admit
# Patient 292: Risk = 10.00% -> No Need to Admit
# Patient 293: Risk = 4.00% -> No Need to Admit
# Patient 294: Risk = 12.00% -> No Need to Admit
# Patient 295: Risk = 4.00% -> No Need to Admit
# Patient 296: Risk = 70.00% -> No Need to Admit
# Patient 297: Risk = 2.00% -> No Need to Admit
# Patient 298: Risk = 75.00% -> Admit
# Patient 299: Risk = 15.00% -> No Need to Admit
# Patient 300: Risk = 3.00% -> No Need to Admit
# Patient 301: Risk = 6.00% -> No Need to Admit
# Patient 302: Risk = 13.00% -> No Need to Admit
# Patient 303: Risk = 12.00% -> No Need to Admit
# Patient 304: Risk = 62.00% -> No Need to Admit
# Patient 305: Risk = 6.00% -> No Need to Admit
# Patient 306: Risk = 15.00% -> No Need to Admit
# Patient 307: Risk = 7.00% -> No Need to Admit
# Patient 308: Risk = 4.00% -> No Need to Admit
# Patient 309: Risk = 2.00% -> No Need to Admit
# Patient 310: Risk = 67.00% -> No Need to Admit
# Patient 311: Risk = 10.00% -> No Need to Admit
# Patient 312: Risk = 4.00% -> No Need to Admit
# Patient 313: Risk = 72.00% -> Admit
# Patient 314: Risk = 5.00% -> No Need to Admit
# Patient 315: Risk = 7.00% -> No Need to Admit
# Patient 316: Risk = 6.00% -> No Need to Admit
# Patient 317: Risk = 7.00% -> No Need to Admit
# Patient 318: Risk = 1.00% -> No Need to Admit
# Patient 319: Risk = 7.00% -> No Need to Admit
# Patient 320: Risk = 0.00% -> No Need to Admit
# Patient 321: Risk = 21.00% -> No Need to Admit
# Patient 322: Risk = 17.00% -> No Need to Admit
# Patient 323: Risk = 11.00% -> No Need to Admit
# Patient 324: Risk = 72.00% -> Admit
# Patient 325: Risk = 71.00% -> Admit
# Patient 326: Risk = 6.00% -> No Need to Admit
# Patient 327: Risk = 12.00% -> No Need to Admit
# Patient 328: Risk = 3.00% -> No Need to Admit
# Patient 329: Risk = 10.00% -> No Need to Admit
# Patient 330: Risk = 75.00% -> Admit
# Patient 331: Risk = 2.00% -> No Need to Admit
# Patient 332: Risk = 19.00% -> No Need to Admit
# Patient 333: Risk = 9.00% -> No Need to Admit
# Patient 334: Risk = 12.00% -> No Need to Admit
# Patient 335: Risk = 12.00% -> No Need to Admit
# Patient 336: Risk = 5.00% -> No Need to Admit
# Patient 337: Risk = 9.00% -> No Need to Admit
# Patient 338: Risk = 8.00% -> No Need to Admit
# Patient 339: Risk = 9.00% -> No Need to Admit
# Patient 340: Risk = 5.00% -> No Need to Admit
# Patient 341: Risk = 5.00% -> No Need to Admit
# Patient 342: Risk = 70.00% -> No Need to Admit
# Patient 343: Risk = 8.00% -> No Need to Admit
# Patient 344: Risk = 71.00% -> Admit
# Patient 345: Risk = 9.00% -> No Need to Admit
# Patient 346: Risk = 4.00% -> No Need to Admit
# Patient 347: Risk = 7.00% -> No Need to Admit
# Patient 348: Risk = 9.00% -> No Need to Admit
# Patient 349: Risk = 60.00% -> No Need to Admit
# Patient 350: Risk = 3.00% -> No Need to Admit
# Patient 351: Risk = 8.00% -> No Need to Admit
# Patient 352: Risk = 69.00% -> No Need to Admit
# Patient 353: Risk = 3.00% -> No Need to Admit
# Patient 354: Risk = 2.00% -> No Need to Admit
# Patient 355: Risk = 9.00% -> No Need to Admit
# Patient 356: Risk = 7.00% -> No Need to Admit
# Patient 357: Risk = 8.00% -> No Need to Admit
# Patient 358: Risk = 9.00% -> No Need to Admit
# Patient 359: Risk = 68.00% -> No Need to Admit
# Patient 360: Risk = 82.00% -> Admit
# Patient 361: Risk = 9.00% -> No Need to Admit
# Patient 362: Risk = 14.00% -> No Need to Admit
# Patient 363: Risk = 9.00% -> No Need to Admit
# Patient 364: Risk = 9.00% -> No Need to Admit
# Patient 365: Risk = 5.00% -> No Need to Admit
# Patient 366: Risk = 67.00% -> No Need to Admit
# Patient 367: Risk = 9.00% -> No Need to Admit
# Patient 368: Risk = 7.00% -> No Need to Admit
# Patient 369: Risk = 11.00% -> No Need to Admit
# Patient 370: Risk = 13.00% -> No Need to Admit
# Patient 371: Risk = 1.00% -> No Need to Admit
# Patient 372: Risk = 5.00% -> No Need to Admit
# Patient 373: Risk = 3.00% -> No Need to Admit
# Patient 374: Risk = 7.00% -> No Need to Admit
# Patient 375: Risk = 9.00% -> No Need to Admit
# Patient 376: Risk = 8.00% -> No Need to Admit
# Patient 377: Risk = 69.00% -> No Need to Admit
# Patient 378: Risk = 7.00% -> No Need to Admit
# Patient 379: Risk = 3.00% -> No Need to Admit
# Patient 380: Risk = 3.00% -> No Need to Admit
# Patient 381: Risk = 9.00% -> No Need to Admit
# Patient 382: Risk = 65.00% -> No Need to Admit
# Patient 383: Risk = 8.00% -> No Need to Admit
# Patient 384: Risk = 68.00% -> No Need to Admit
# Patient 385: Risk = 0.00% -> No Need to Admit
# Patient 386: Risk = 11.00% -> No Need to Admit
# Patient 387: Risk = 11.00% -> No Need to Admit
# Patient 388: Risk = 3.00% -> No Need to Admit
# Patient 389: Risk = 2.00% -> No Need to Admit
# Patient 390: Risk = 72.00% -> Admit
# Patient 391: Risk = 10.00% -> No Need to Admit
# Patient 392: Risk = 5.00% -> No Need to Admit
# Patient 393: Risk = 4.00% -> No Need to Admit
# Patient 394: Risk = 16.00% -> No Need to Admit
# Patient 395: Risk = 5.00% -> No Need to Admit
# Patient 396: Risk = 9.00% -> No Need to Admit
# Patient 397: Risk = 18.00% -> No Need to Admit
# Patient 398: Risk = 6.00% -> No Need to Admit
# Patient 399: Risk = 1.00% -> No Need to Admit
# Patient 400: Risk = 3.00% -> No Need to Admit
# Patient 401: Risk = 8.00% -> No Need to Admit
# Patient 402: Risk = 70.00% -> No Need to Admit
# Patient 403: Risk = 63.00% -> No Need to Admit
# Patient 404: Risk = 4.00% -> No Need to Admit
# Patient 405: Risk = 3.00% -> No Need to Admit
# Patient 406: Risk = 9.00% -> No Need to Admit
# Patient 407: Risk = 4.00% -> No Need to Admit
# Patient 408: Risk = 76.00% -> Admit
# Patient 409: Risk = 10.00% -> No Need to Admit
# Patient 410: Risk = 67.00% -> No Need to Admit
# Patient 411: Risk = 5.00% -> No Need to Admit
# Patient 412: Risk = 13.00% -> No Need to Admit
# Patient 413: Risk = 40.32% -> No Need to Admit
# Patient 414: Risk = 8.00% -> No Need to Admit
# Patient 415: Risk = 12.00% -> No Need to Admit
# Patient 416: Risk = 9.00% -> No Need to Admit
# Patient 417: Risk = 5.00% -> No Need to Admit
# Patient 418: Risk = 8.00% -> No Need to Admit
# Patient 419: Risk = 73.00% -> Admit
# Patient 420: Risk = 5.00% -> No Need to Admit
# Patient 421: Risk = 12.00% -> No Need to Admit
# Patient 422: Risk = 68.00% -> No Need to Admit
# Patient 423: Risk = 63.00% -> No Need to Admit
# Patient 424: Risk = 9.00% -> No Need to Admit
# Patient 425: Risk = 5.00% -> No Need to Admit
# Patient 426: Risk = 2.00% -> No Need to Admit
# Patient 427: Risk = 11.00% -> No Need to Admit
# Patient 428: Risk = 0.00% -> No Need to Admit
# Patient 429: Risk = 5.00% -> No Need to Admit
# Patient 430: Risk = 5.00% -> No Need to Admit
# Patient 431: Risk = 10.00% -> No Need to Admit
# Patient 432: Risk = 5.00% -> No Need to Admit
# Patient 433: Risk = 4.00% -> No Need to Admit
# Patient 434: Risk = 10.00% -> No Need to Admit
# Patient 435: Risk = 4.00% -> No Need to Admit
# Patient 436: Risk = 3.00% -> No Need to Admit
# Patient 437: Risk = 6.00% -> No Need to Admit
# Patient 438: Risk = 68.00% -> No Need to Admit
# Patient 439: Risk = 4.00% -> No Need to Admit
# Patient 440: Risk = 5.00% -> No Need to Admit
# Patient 441: Risk = 2.00% -> No Need to Admit
# Patient 442: Risk = 7.00% -> No Need to Admit
# Patient 443: Risk = 5.00% -> No Need to Admit
# Patient 444: Risk = 9.00% -> No Need to Admit
# Patient 445: Risk = 64.00% -> No Need to Admit
# Patient 446: Risk = 12.00% -> No Need to Admit
# Patient 447: Risk = 15.00% -> No Need to Admit
# Patient 448: Risk = 67.00% -> No Need to Admit
# Patient 449: Risk = 54.00% -> No Need to Admit
# Patient 450: Risk = 11.00% -> No Need to Admit
# Patient 451: Risk = 6.00% -> No Need to Admit
# Patient 452: Risk = 5.00% -> No Need to Admit
# Patient 453: Risk = 3.00% -> No Need to Admit
# Patient 454: Risk = 11.00% -> No Need to Admit
# Patient 455: Risk = 71.00% -> Admit
# Patient 456: Risk = 4.00% -> No Need to Admit
# Patient 457: Risk = 3.00% -> No Need to Admit
# Patient 458: Risk = 14.67% -> No Need to Admit
# Patient 459: Risk = 75.00% -> Admit
# Patient 460: Risk = 12.00% -> No Need to Admit
# Patient 461: Risk = 6.00% -> No Need to Admit
# Patient 462: Risk = 7.00% -> No Need to Admit
# Patient 463: Risk = 14.00% -> No Need to Admit
# Patient 464: Risk = 9.00% -> No Need to Admit
# Patient 465: Risk = 4.00% -> No Need to Admit
# Patient 466: Risk = 15.00% -> No Need to Admit
# Patient 467: Risk = 14.00% -> No Need to Admit
# Patient 468: Risk = 4.00% -> No Need to Admit
# Patient 469: Risk = 13.00% -> No Need to Admit
# Patient 470: Risk = 79.00% -> Admit
# Patient 471: Risk = 4.00% -> No Need to Admit
# Patient 472: Risk = 8.00% -> No Need to Admit
# Patient 473: Risk = 8.00% -> No Need to Admit
# Patient 474: Risk = 8.00% -> No Need to Admit
# Patient 475: Risk = 3.00% -> No Need to Admit
# Patient 476: Risk = 15.00% -> No Need to Admit
# Patient 477: Risk = 8.00% -> No Need to Admit
# Patient 478: Risk = 11.00% -> No Need to Admit
# Patient 479: Risk = 7.00% -> No Need to Admit
# Patient 480: Risk = 67.00% -> No Need to Admit
# Patient 481: Risk = 3.00% -> No Need to Admit
# Patient 482: Risk = 12.00% -> No Need to Admit
# Patient 483: Risk = 6.00% -> No Need to Admit
# Patient 484: Risk = 1.83% -> No Need to Admit
# Patient 485: Risk = 10.00% -> No Need to Admit
# Patient 486: Risk = 68.00% -> No Need to Admit
# Patient 487: Risk = 10.00% -> No Need to Admit
# Patient 488: Risk = 2.00% -> No Need to Admit
# Patient 489: Risk = 7.00% -> No Need to Admit
# Patient 490: Risk = 73.00% -> Admit
# Patient 491: Risk = 4.00% -> No Need to Admit
# Patient 492: Risk = 8.00% -> No Need to Admit
# Patient 493: Risk = 11.00% -> No Need to Admit
# Patient 494: Risk = 3.00% -> No Need to Admit
# Patient 495: Risk = 10.00% -> No Need to Admit
# Patient 496: Risk = 7.00% -> No Need to Admit
# Patient 497: Risk = 14.00% -> No Need to Admit
# Patient 498: Risk = 8.00% -> No Need to Admit
# Patient 499: Risk = 6.00% -> No Need to Admit
# Patient 500: Risk = 4.00% -> No Need to Admit
# Patient 501: Risk = 15.00% -> No Need to Admit
# Patient 502: Risk = 5.00% -> No Need to Admit
# Patient 503: Risk = 3.00% -> No Need to Admit
# Patient 504: Risk = 10.00% -> No Need to Admit
# Patient 505: Risk = 5.00% -> No Need to Admit
# Patient 506: Risk = 14.00% -> No Need to Admit
# Patient 507: Risk = 9.00% -> No Need to Admit
# Patient 508: Risk = 9.00% -> No Need to Admit
# Patient 509: Risk = 5.00% -> No Need to Admit
# Patient 510: Risk = 9.00% -> No Need to Admit
# Patient 511: Risk = 9.00% -> No Need to Admit
# Patient 512: Risk = 9.00% -> No Need to Admit
# Patient 513: Risk = 3.00% -> No Need to Admit
# Patient 514: Risk = 7.00% -> No Need to Admit
# Patient 515: Risk = 5.00% -> No Need to Admit
# Patient 516: Risk = 10.00% -> No Need to Admit
# Patient 517: Risk = 74.00% -> Admit
# Patient 518: Risk = 62.00% -> No Need to Admit
# Patient 519: Risk = 5.00% -> No Need to Admit
# Patient 520: Risk = 76.00% -> Admit
# Patient 521: Risk = 7.00% -> No Need to Admit
# Patient 522: Risk = 67.00% -> No Need to Admit
# Patient 523: Risk = 67.00% -> No Need to Admit
# Patient 524: Risk = 76.00% -> Admit
# Patient 525: Risk = 15.00% -> No Need to Admit
# Patient 526: Risk = 13.00% -> No Need to Admit
# Patient 527: Risk = 2.00% -> No Need to Admit
# Patient 528: Risk = 3.00% -> No Need to Admit
# Patient 529: Risk = 9.00% -> No Need to Admit
# Patient 530: Risk = 78.00% -> Admit
# Patient 531: Risk = 8.00% -> No Need to Admit
# Patient 532: Risk = 10.00% -> No Need to Admit
# Patient 533: Risk = 5.00% -> No Need to Admit
# Patient 534: Risk = 3.00% -> No Need to Admit
# Patient 535: Risk = 64.00% -> No Need to Admit
# Patient 536: Risk = 62.00% -> No Need to Admit
# Patient 537: Risk = 11.00% -> No Need to Admit
# Patient 538: Risk = 10.00% -> No Need to Admit
# Patient 539: Risk = 8.00% -> No Need to Admit
# Patient 540: Risk = 9.00% -> No Need to Admit
# Patient 541: Risk = 19.00% -> No Need to Admit
# Patient 542: Risk = 3.00% -> No Need to Admit
# Patient 543: Risk = 3.00% -> No Need to Admit
# Patient 544: Risk = 9.00% -> No Need to Admit
# Patient 545: Risk = 3.00% -> No Need to Admit
# Patient 546: Risk = 4.00% -> No Need to Admit
# Patient 547: Risk = 4.00% -> No Need to Admit
# Patient 548: Risk = 5.00% -> No Need to Admit
# Patient 549: Risk = 72.00% -> Admit
# Patient 550: Risk = 15.00% -> No Need to Admit
# Patient 551: Risk = 6.00% -> No Need to Admit
# Patient 552: Risk = 7.00% -> No Need to Admit
# Patient 553: Risk = 72.00% -> Admit
# Patient 554: Risk = 8.00% -> No Need to Admit
# Patient 555: Risk = 17.00% -> No Need to Admit
# Patient 556: Risk = 10.00% -> No Need to Admit
# Patient 557: Risk = 13.00% -> No Need to Admit
# Patient 558: Risk = 19.00% -> No Need to Admit
# Patient 559: Risk = 14.00% -> No Need to Admit
# Patient 560: Risk = 67.00% -> No Need to Admit
# Patient 561: Risk = 6.00% -> No Need to Admit
# Patient 562: Risk = 15.00% -> No Need to Admit
# Patient 563: Risk = 63.00% -> No Need to Admit
# Patient 564: Risk = 4.00% -> No Need to Admit
# Patient 565: Risk = 14.00% -> No Need to Admit
# Patient 566: Risk = 3.00% -> No Need to Admit
# Patient 567: Risk = 67.00% -> No Need to Admit
# Patient 568: Risk = 16.00% -> No Need to Admit
# Patient 569: Risk = 4.00% -> No Need to Admit
# Patient 570: Risk = 9.00% -> No Need to Admit
# Patient 571: Risk = 78.00% -> Admit
# Patient 572: Risk = 67.00% -> No Need to Admit
# Patient 573: Risk = 7.00% -> No Need to Admit
# Patient 574: Risk = 3.00% -> No Need to Admit
# Patient 575: Risk = 6.00% -> No Need to Admit
# Patient 576: Risk = 7.00% -> No Need to Admit
# Patient 577: Risk = 75.00% -> Admit
# Patient 578: Risk = 5.00% -> No Need to Admit
# Patient 579: Risk = 5.00% -> No Need to Admit
# Patient 580: Risk = 9.00% -> No Need to Admit
# Patient 581: Risk = 7.00% -> No Need to Admit
# Patient 582: Risk = 8.00% -> No Need to Admit
# Patient 583: Risk = 18.00% -> No Need to Admit
# Patient 584: Risk = 9.00% -> No Need to Admit
# Patient 585: Risk = 2.00% -> No Need to Admit
# Patient 586: Risk = 3.00% -> No Need to Admit
# Patient 587: Risk = 6.00% -> No Need to Admit
# Patient 588: Risk = 72.00% -> Admit
# Patient 589: Risk = 9.00% -> No Need to Admit
# Patient 590: Risk = 70.00% -> No Need to Admit
# Patient 591: Risk = 6.00% -> No Need to Admit
# Patient 592: Risk = 75.00% -> Admit
# Patient 593: Risk = 20.00% -> No Need to Admit
# Patient 594: Risk = 5.00% -> No Need to Admit
# Patient 595: Risk = 10.00% -> No Need to Admit
# Patient 596: Risk = 16.00% -> No Need to Admit
# Patient 597: Risk = 71.00% -> Admit
# Patient 598: Risk = 6.00% -> No Need to Admit
# Patient 599: Risk = 2.00% -> No Need to Admit
# Patient 600: Risk = 9.00% -> No Need to Admit
# Patient 601: Risk = 6.00% -> No Need to Admit
# Patient 602: Risk = 1.00% -> No Need to Admit
# Patient 603: Risk = 5.00% -> No Need to Admit
# Patient 604: Risk = 12.00% -> No Need to Admit
# Patient 605: Risk = 8.00% -> No Need to Admit
# Patient 606: Risk = 5.00% -> No Need to Admit
# Patient 607: Risk = 7.00% -> No Need to Admit
# Patient 608: Risk = 17.00% -> No Need to Admit
# Patient 609: Risk = 64.00% -> No Need to Admit
# Patient 610: Risk = 9.00% -> No Need to Admit
# Patient 611: Risk = 9.00% -> No Need to Admit
# Patient 612: Risk = 7.00% -> No Need to Admit
# Patient 613: Risk = 3.00% -> No Need to Admit
# Patient 614: Risk = 6.00% -> No Need to Admit
# Patient 615: Risk = 5.00% -> No Need to Admit
# Patient 616: Risk = 10.00% -> No Need to Admit
# Patient 617: Risk = 11.00% -> No Need to Admit
# Patient 618: Risk = 11.00% -> No Need to Admit
# Patient 619: Risk = 6.00% -> No Need to Admit
# Patient 620: Risk = 5.00% -> No Need to Admit
# Patient 621: Risk = 13.00% -> No Need to Admit
# Patient 622: Risk = 7.00% -> No Need to Admit
# Patient 623: Risk = 5.00% -> No Need to Admit
# Patient 624: Risk = 3.00% -> No Need to Admit
# Patient 625: Risk = 82.00% -> Admit
# Patient 626: Risk = 6.00% -> No Need to Admit
# Patient 627: Risk = 79.00% -> Admit
# Patient 628: Risk = 3.00% -> No Need to Admit
# Patient 629: Risk = 6.00% -> No Need to Admit
# Patient 630: Risk = 4.00% -> No Need to Admit
# Patient 631: Risk = 6.00% -> No Need to Admit
# Patient 632: Risk = 8.00% -> No Need to Admit
# Patient 633: Risk = 10.00% -> No Need to Admit
# Patient 634: Risk = 9.00% -> No Need to Admit
# Patient 635: Risk = 5.00% -> No Need to Admit
# Patient 636: Risk = 4.00% -> No Need to Admit
# Patient 637: Risk = 10.00% -> No Need to Admit
# Patient 638: Risk = 64.00% -> No Need to Admit
# Patient 639: Risk = 12.00% -> No Need to Admit
# Patient 640: Risk = 11.00% -> No Need to Admit
# Patient 641: Risk = 80.00% -> Admit
# Patient 642: Risk = 13.00% -> No Need to Admit
# Patient 643: Risk = 5.00% -> No Need to Admit
# Patient 644: Risk = 77.00% -> Admit
# Patient 645: Risk = 5.00% -> No Need to Admit
# Patient 646: Risk = 5.00% -> No Need to Admit
# Patient 647: Risk = 8.00% -> No Need to Admit
# Patient 648: Risk = 4.00% -> No Need to Admit
# Patient 649: Risk = 12.00% -> No Need to Admit
# Patient 650: Risk = 10.00% -> No Need to Admit
# Patient 651: Risk = 7.00% -> No Need to Admit
# Patient 652: Risk = 7.00% -> No Need to Admit
# Patient 653: Risk = 1.00% -> No Need to Admit
# Patient 654: Risk = 13.00% -> No Need to Admit
# Patient 655: Risk = 12.00% -> No Need to Admit
# Patient 656: Risk = 71.00% -> Admit
# Patient 657: Risk = 7.00% -> No Need to Admit
# Patient 658: Risk = 65.00% -> No Need to Admit
# Patient 659: Risk = 0.00% -> No Need to Admit
# Patient 660: Risk = 2.00% -> No Need to Admit
# Patient 661: Risk = 9.00% -> No Need to Admit
# Patient 662: Risk = 11.90% -> No Need to Admit
# Patient 663: Risk = 0.00% -> No Need to Admit
# Patient 664: Risk = 68.00% -> No Need to Admit
# Patient 665: Risk = 10.00% -> No Need to Admit
# Patient 666: Risk = 70.00% -> No Need to Admit
# Patient 667: Risk = 8.00% -> No Need to Admit
# Patient 668: Risk = 74.00% -> Admit
# Patient 669: Risk = 0.00% -> No Need to Admit
# Patient 670: Risk = 71.00% -> Admit
# Patient 671: Risk = 4.00% -> No Need to Admit
# Patient 672: Risk = 75.00% -> Admit
# Patient 673: Risk = 6.00% -> No Need to Admit
# Patient 674: Risk = 6.00% -> No Need to Admit
# Patient 675: Risk = 5.00% -> No Need to Admit
# Patient 676: Risk = 24.00% -> No Need to Admit
# Patient 677: Risk = 7.00% -> No Need to Admit
# Patient 678: Risk = 68.00% -> No Need to Admit
# Patient 679: Risk = 12.00% -> No Need to Admit
# Patient 680: Risk = 1.00% -> No Need to Admit
# Patient 681: Risk = 4.00% -> No Need to Admit
# Patient 682: Risk = 11.00% -> No Need to Admit
# Patient 683: Risk = 6.00% -> No Need to Admit
# Patient 684: Risk = 72.00% -> Admit
# Patient 685: Risk = 2.00% -> No Need to Admit
# Patient 686: Risk = 8.00% -> No Need to Admit
# Patient 687: Risk = 6.00% -> No Need to Admit
# Patient 688: Risk = 24.00% -> No Need to Admit
# Patient 689: Risk = 16.00% -> No Need to Admit
# Patient 690: Risk = 9.00% -> No Need to Admit
# Patient 691: Risk = 1.00% -> No Need to Admit
# Patient 692: Risk = 11.00% -> No Need to Admit
# Patient 693: Risk = 66.00% -> No Need to Admit
# Patient 694: Risk = 12.00% -> No Need to Admit
# Patient 695: Risk = 78.00% -> Admit
# Patient 696: Risk = 8.00% -> No Need to Admit
# Patient 697: Risk = 1.00% -> No Need to Admit
# Patient 698: Risk = 0.00% -> No Need to Admit
# Patient 699: Risk = 14.00% -> No Need to Admit
# Patient 700: Risk = 2.00% -> No Need to Admit
# Patient 701: Risk = 4.00% -> No Need to Admit
# Patient 702: Risk = 3.00% -> No Need to Admit
# Patient 703: Risk = 3.00% -> No Need to Admit
# Patient 704: Risk = 5.00% -> No Need to Admit
# Patient 705: Risk = 13.00% -> No Need to Admit
# Patient 706: Risk = 65.00% -> No Need to Admit
# Patient 707: Risk = 14.00% -> No Need to Admit
# Patient 708: Risk = 17.00% -> No Need to Admit
# Patient 709: Risk = 77.00% -> Admit
# Patient 710: Risk = 75.00% -> Admit
# Patient 711: Risk = 6.00% -> No Need to Admit
# Patient 712: Risk = 6.00% -> No Need to Admit
# Patient 713: Risk = 63.00% -> No Need to Admit
# Patient 714: Risk = 13.00% -> No Need to Admit
# Patient 715: Risk = 12.00% -> No Need to Admit
# Patient 716: Risk = 0.00% -> No Need to Admit
# Patient 717: Risk = 9.00% -> No Need to Admit
# Patient 718: Risk = 72.00% -> Admit
# Patient 719: Risk = 7.00% -> No Need to Admit
# Patient 720: Risk = 75.00% -> Admit
# Patient 721: Risk = 4.00% -> No Need to Admit
# Patient 722: Risk = 3.00% -> No Need to Admit
# Patient 723: Risk = 9.00% -> No Need to Admit
# Patient 724: Risk = 58.08% -> No Need to Admit
# Patient 725: Risk = 6.00% -> No Need to Admit
# Patient 726: Risk = 6.00% -> No Need to Admit
# Patient 727: Risk = 8.00% -> No Need to Admit
# Patient 728: Risk = 3.00% -> No Need to Admit
# Patient 729: Risk = 6.00% -> No Need to Admit
# Patient 730: Risk = 6.00% -> No Need to Admit
# Patient 731: Risk = 77.00% -> Admit
# Patient 732: Risk = 15.00% -> No Need to Admit
# Patient 733: Risk = 12.00% -> No Need to Admit
# Patient 734: Risk = 2.00% -> No Need to Admit
# Patient 735: Risk = 10.00% -> No Need to Admit
# Patient 736: Risk = 5.00% -> No Need to Admit
# Patient 737: Risk = 63.00% -> No Need to Admit
# Patient 738: Risk = 6.00% -> No Need to Admit
# Patient 739: Risk = 71.00% -> Admit
# Patient 740: Risk = 57.00% -> No Need to Admit
# Patient 741: Risk = 13.00% -> No Need to Admit
# Patient 742: Risk = 5.00% -> No Need to Admit
# Patient 743: Risk = 12.00% -> No Need to Admit
# Patient 744: Risk = 8.00% -> No Need to Admit
# Patient 745: Risk = 8.00% -> No Need to Admit
# Patient 746: Risk = 13.00% -> No Need to Admit
# Patient 747: Risk = 5.00% -> No Need to Admit
# Patient 748: Risk = 69.00% -> No Need to Admit
# Patient 749: Risk = 8.00% -> No Need to Admit
# Patient 750: Risk = 6.00% -> No Need to Admit
# Patient 751: Risk = 4.00% -> No Need to Admit
# Patient 752: Risk = 6.00% -> No Need to Admit
# Patient 753: Risk = 5.00% -> No Need to Admit
# Patient 754: Risk = 69.00% -> No Need to Admit
# Patient 755: Risk = 24.00% -> No Need to Admit
# Patient 756: Risk = 8.00% -> No Need to Admit
# Patient 757: Risk = 11.00% -> No Need to Admit
# Patient 758: Risk = 9.00% -> No Need to Admit
# Patient 759: Risk = 8.00% -> No Need to Admit
# Patient 760: Risk = 69.00% -> No Need to Admit
# Patient 761: Risk = 68.00% -> No Need to Admit
# Patient 762: Risk = 9.00% -> No Need to Admit
# Patient 763: Risk = 2.00% -> No Need to Admit
# Patient 764: Risk = 11.00% -> No Need to Admit
# Patient 765: Risk = 9.00% -> No Need to Admit
# Patient 766: Risk = 5.00% -> No Need to Admit
# Patient 767: Risk = 5.00% -> No Need to Admit
# Patient 768: Risk = 3.00% -> No Need to Admit
# Patient 769: Risk = 5.00% -> No Need to Admit
# Patient 770: Risk = 11.00% -> No Need to Admit
# Patient 771: Risk = 8.00% -> No Need to Admit
# Patient 772: Risk = 6.00% -> No Need to Admit
# Patient 773: Risk = 10.00% -> No Need to Admit
# Patient 774: Risk = 7.00% -> No Need to Admit
# Patient 775: Risk = 67.00% -> No Need to Admit
# Patient 776: Risk = 23.00% -> No Need to Admit
# Patient 777: Risk = 82.00% -> Admit
# Patient 778: Risk = 9.00% -> No Need to Admit
# Patient 779: Risk = 2.00% -> No Need to Admit
# Patient 780: Risk = 6.00% -> No Need to Admit
# Patient 781: Risk = 8.00% -> No Need to Admit
# Patient 782: Risk = 9.00% -> No Need to Admit
# Patient 783: Risk = 4.00% -> No Need to Admit
# Patient 784: Risk = 4.00% -> No Need to Admit
# Patient 785: Risk = 7.00% -> No Need to Admit
# Patient 786: Risk = 7.00% -> No Need to Admit
# Patient 787: Risk = 17.00% -> No Need to Admit
# Patient 788: Risk = 69.00% -> No Need to Admit
# Patient 789: Risk = 65.00% -> No Need to Admit
# Patient 790: Risk = 4.00% -> No Need to Admit
# Patient 791: Risk = 13.00% -> No Need to Admit
# Patient 792: Risk = 6.00% -> No Need to Admit
# Patient 793: Risk = 71.00% -> Admit
# Patient 794: Risk = 13.00% -> No Need to Admit
# Patient 795: Risk = 68.00% -> No Need to Admit
# Patient 796: Risk = 13.00% -> No Need to Admit
# Patient 797: Risk = 75.00% -> Admit
# Patient 798: Risk = 4.00% -> No Need to Admit
# Patient 799: Risk = 7.00% -> No Need to Admit
# Patient 800: Risk = 12.00% -> No Need to Admit
# Patient 801: Risk = 72.00% -> Admit
# Patient 802: Risk = 76.00% -> Admit
# Patient 803: Risk = 16.00% -> No Need to Admit
# Patient 804: Risk = 2.00% -> No Need to Admit
# Patient 805: Risk = 3.00% -> No Need to Admit
# Patient 806: Risk = 2.00% -> No Need to Admit
# Patient 807: Risk = 61.00% -> No Need to Admit
# Patient 808: Risk = 2.00% -> No Need to Admit
# Patient 809: Risk = 5.00% -> No Need to Admit
# Patient 810: Risk = 8.00% -> No Need to Admit
# Patient 811: Risk = 8.00% -> No Need to Admit
# Patient 812: Risk = 71.00% -> Admit
# Patient 813: Risk = 9.00% -> No Need to Admit
# Patient 814: Risk = 7.00% -> No Need to Admit
# Patient 815: Risk = 5.00% -> No Need to Admit
# Patient 816: Risk = 6.00% -> No Need to Admit
# Patient 817: Risk = 6.00% -> No Need to Admit
# Patient 818: Risk = 77.00% -> Admit
# Patient 819: Risk = 6.00% -> No Need to Admit
# Patient 820: Risk = 72.00% -> Admit
# Patient 821: Risk = 7.00% -> No Need to Admit
# Patient 822: Risk = 74.00% -> Admit
# Patient 823: Risk = 9.00% -> No Need to Admit
# Patient 824: Risk = 6.00% -> No Need to Admit
# Patient 825: Risk = 2.00% -> No Need to Admit
# Patient 826: Risk = 70.00% -> No Need to Admit
# Patient 827: Risk = 1.00% -> No Need to Admit
# Patient 828: Risk = 9.00% -> No Need to Admit
# Patient 829: Risk = 72.00% -> Admit
# Patient 830: Risk = 5.00% -> No Need to Admit
# Patient 831: Risk = 12.00% -> No Need to Admit
# Patient 832: Risk = 4.00% -> No Need to Admit
# Patient 833: Risk = 5.00% -> No Need to Admit
# Patient 834: Risk = 1.00% -> No Need to Admit
# Patient 835: Risk = 4.00% -> No Need to Admit
# Patient 836: Risk = 4.00% -> No Need to Admit
# Patient 837: Risk = 3.00% -> No Need to Admit
# Patient 838: Risk = 19.00% -> No Need to Admit
# Patient 839: Risk = 5.00% -> No Need to Admit
# Patient 840: Risk = 11.00% -> No Need to Admit
# Patient 841: Risk = 10.00% -> No Need to Admit
# Patient 842: Risk = 80.00% -> Admit
# Patient 843: Risk = 77.00% -> Admit
# Patient 844: Risk = 69.00% -> No Need to Admit
# Patient 845: Risk = 16.00% -> No Need to Admit
# Patient 846: Risk = 66.00% -> No Need to Admit
# Patient 847: Risk = 66.00% -> No Need to Admit
# Patient 848: Risk = 9.00% -> No Need to Admit
# Patient 849: Risk = 8.00% -> No Need to Admit
# Patient 850: Risk = 6.00% -> No Need to Admit
# Patient 851: Risk = 4.00% -> No Need to Admit
# Patient 852: Risk = 73.00% -> Admit
# Patient 853: Risk = 5.00% -> No Need to Admit
# Patient 854: Risk = 7.00% -> No Need to Admit
# Patient 855: Risk = 3.00% -> No Need to Admit
# Patient 856: Risk = 8.00% -> No Need to Admit
# Patient 857: Risk = 2.00% -> No Need to Admit
# Patient 858: Risk = 73.00% -> Admit
# Patient 859: Risk = 5.00% -> No Need to Admit
# Patient 860: Risk = 67.00% -> No Need to Admit
# Patient 861: Risk = 8.00% -> No Need to Admit
# Patient 862: Risk = 7.00% -> No Need to Admit
# Patient 863: Risk = 6.00% -> No Need to Admit
# Patient 864: Risk = 77.83% -> Admit
# Patient 865: Risk = 11.00% -> No Need to Admit
# Patient 866: Risk = 5.00% -> No Need to Admit
# Patient 867: Risk = 13.00% -> No Need to Admit
# Patient 868: Risk = 71.00% -> Admit
# Patient 869: Risk = 5.00% -> No Need to Admit
# Patient 870: Risk = 11.00% -> No Need to Admit
# Patient 871: Risk = 8.00% -> No Need to Admit
# Patient 872: Risk = 6.00% -> No Need to Admit
# Patient 873: Risk = 70.00% -> No Need to Admit
# Patient 874: Risk = 65.00% -> No Need to Admit
# Patient 875: Risk = 8.00% -> No Need to Admit
# Patient 876: Risk = 64.00% -> No Need to Admit
# Patient 877: Risk = 5.00% -> No Need to Admit
# Patient 878: Risk = 8.00% -> No Need to Admit
# Patient 879: Risk = 76.00% -> Admit
# Patient 880: Risk = 7.00% -> No Need to Admit
# Patient 881: Risk = 3.00% -> No Need to Admit
# Patient 882: Risk = 11.00% -> No Need to Admit
# Patient 883: Risk = 20.00% -> No Need to Admit
# Patient 884: Risk = 4.00% -> No Need to Admit
# Patient 885: Risk = 0.00% -> No Need to Admit
# Patient 886: Risk = 64.00% -> No Need to Admit
# Patient 887: Risk = 8.00% -> No Need to Admit
# Patient 888: Risk = 11.00% -> No Need to Admit
# Patient 889: Risk = 70.00% -> No Need to Admit
# Patient 890: Risk = 10.00% -> No Need to Admit
# Patient 891: Risk = 8.00% -> No Need to Admit
# Patient 892: Risk = 9.00% -> No Need to Admit
# Patient 893: Risk = 10.00% -> No Need to Admit
# Patient 894: Risk = 9.00% -> No Need to Admit
# Patient 895: Risk = 0.00% -> No Need to Admit
# Patient 896: Risk = 76.00% -> Admit
# Patient 897: Risk = 62.00% -> No Need to Admit
# Patient 898: Risk = 72.00% -> Admit
# Patient 899: Risk = 14.00% -> No Need to Admit
# Patient 900: Risk = 3.00% -> No Need to Admit
# Patient 901: Risk = 70.00% -> No Need to Admit
# Patient 902: Risk = 1.00% -> No Need to Admit
# Patient 903: Risk = 9.00% -> No Need to Admit
# Patient 904: Risk = 16.00% -> No Need to Admit
# Patient 905: Risk = 4.00% -> No Need to Admit
# Patient 906: Risk = 2.00% -> No Need to Admit
# Patient 907: Risk = 5.00% -> No Need to Admit
# Patient 908: Risk = 4.75% -> No Need to Admit
# Patient 909: Risk = 6.00% -> No Need to Admit
# Patient 910: Risk = 15.00% -> No Need to Admit
# Patient 911: Risk = 71.00% -> Admit
# Patient 912: Risk = 75.00% -> Admit
# Patient 913: Risk = 4.00% -> No Need to Admit
# Patient 914: Risk = 14.00% -> No Need to Admit
# Patient 915: Risk = 3.00% -> No Need to Admit
# Patient 916: Risk = 8.00% -> No Need to Admit
# Patient 917: Risk = 4.00% -> No Need to Admit
# Patient 918: Risk = 3.00% -> No Need to Admit
# Patient 919: Risk = 67.00% -> No Need to Admit
# Patient 920: Risk = 8.00% -> No Need to Admit
# Patient 921: Risk = 16.00% -> No Need to Admit
# Patient 922: Risk = 9.00% -> No Need to Admit
# Patient 923: Risk = 7.00% -> No Need to Admit
# Patient 924: Risk = 2.00% -> No Need to Admit
# Patient 925: Risk = 15.00% -> No Need to Admit
# Patient 926: Risk = 3.00% -> No Need to Admit
# Patient 927: Risk = 7.00% -> No Need to Admit
# Patient 928: Risk = 6.00% -> No Need to Admit
# Patient 929: Risk = 10.00% -> No Need to Admit
# Patient 930: Risk = 2.00% -> No Need to Admit
# Patient 931: Risk = 15.00% -> No Need to Admit
# Patient 932: Risk = 1.00% -> No Need to Admit
# Patient 933: Risk = 13.00% -> No Need to Admit
# Patient 934: Risk = 4.00% -> No Need to Admit
# Patient 935: Risk = 8.00% -> No Need to Admit
# Patient 936: Risk = 3.00% -> No Need to Admit
# Patient 937: Risk = 9.00% -> No Need to Admit
# Patient 938: Risk = 10.00% -> No Need to Admit
# Patient 939: Risk = 14.00% -> No Need to Admit
# Patient 940: Risk = 7.00% -> No Need to Admit
# Patient 941: Risk = 68.00% -> No Need to Admit
# Patient 942: Risk = 56.00% -> No Need to Admit
# Patient 943: Risk = 2.00% -> No Need to Admit
# Patient 944: Risk = 78.00% -> Admit
# Patient 945: Risk = 11.00% -> No Need to Admit
# Patient 946: Risk = 69.00% -> No Need to Admit
# Patient 947: Risk = 5.00% -> No Need to Admit
# Patient 948: Risk = 8.00% -> No Need to Admit
# Patient 949: Risk = 3.00% -> No Need to Admit
# Patient 950: Risk = 1.00% -> No Need to Admit
# Patient 951: Risk = 12.00% -> No Need to Admit
# Patient 952: Risk = 5.00% -> No Need to Admit
# Patient 953: Risk = 0.00% -> No Need to Admit
# Patient 954: Risk = 3.00% -> No Need to Admit
# Patient 955: Risk = 74.00% -> Admit
# Patient 956: Risk = 7.00% -> No Need to Admit
# Patient 957: Risk = 6.00% -> No Need to Admit
# Patient 958: Risk = 2.00% -> No Need to Admit
# Patient 959: Risk = 8.00% -> No Need to Admit
# Patient 960: Risk = 8.00% -> No Need to Admit
# Patient 961: Risk = 8.00% -> No Need to Admit
# Patient 962: Risk = 75.00% -> Admit
# Patient 963: Risk = 3.00% -> No Need to Admit
# Patient 964: Risk = 10.00% -> No Need to Admit
# Patient 965: Risk = 12.00% -> No Need to Admit
# Patient 966: Risk = 9.00% -> No Need to Admit
# Patient 967: Risk = 8.00% -> No Need to Admit
# Patient 968: Risk = 6.00% -> No Need to Admit
# Patient 969: Risk = 9.00% -> No Need to Admit
# Patient 970: Risk = 7.00% -> No Need to Admit
# Patient 971: Risk = 13.00% -> No Need to Admit
# Patient 972: Risk = 71.00% -> Admit
# Patient 973: Risk = 3.00% -> No Need to Admit
# Patient 974: Risk = 12.00% -> No Need to Admit
# Patient 975: Risk = 5.00% -> No Need to Admit
# Patient 976: Risk = 71.00% -> Admit
# Patient 977: Risk = 13.00% -> No Need to Admit
# Patient 978: Risk = 67.00% -> No Need to Admit
# Patient 979: Risk = 2.00% -> No Need to Admit
# Patient 980: Risk = 4.00% -> No Need to Admit
# Patient 981: Risk = 7.00% -> No Need to Admit
# Patient 982: Risk = 2.00% -> No Need to Admit
# Patient 983: Risk = 18.00% -> No Need to Admit
# Patient 984: Risk = 4.00% -> No Need to Admit
# Patient 985: Risk = 13.00% -> No Need to Admit
# Patient 986: Risk = 12.00% -> No Need to Admit
# Patient 987: Risk = 7.00% -> No Need to Admit
# Patient 988: Risk = 4.00% -> No Need to Admit
# Patient 989: Risk = 11.00% -> No Need to Admit
# Patient 990: Risk = 7.00% -> No Need to Admit
# Patient 991: Risk = 7.00% -> No Need to Admit
# Patient 992: Risk = 8.00% -> No Need to Admit
# Patient 993: Risk = 5.00% -> No Need to Admit
# Patient 994: Risk = 5.00% -> No Need to Admit
# Patient 995: Risk = 1.00% -> No Need to Admit
# Patient 996: Risk = 64.00% -> No Need to Admit
# Patient 997: Risk = 8.00% -> No Need to Admit
# Patient 998: Risk = 15.00% -> No Need to Admit
# Patient 999: Risk = 5.00% -> No Need to Admit
# Patient 1000: Risk = 5.00% -> No Need to Admit
# Patient 1001: Risk = 7.00% -> No Need to Admit
# Patient 1002: Risk = 8.00% -> No Need to Admit
# Patient 1003: Risk = 9.00% -> No Need to Admit
# Patient 1004: Risk = 10.00% -> No Need to Admit
# Patient 1005: Risk = 8.00% -> No Need to Admit
# Patient 1006: Risk = 2.00% -> No Need to Admit
# Patient 1007: Risk = 4.00% -> No Need to Admit
# Patient 1008: Risk = 2.00% -> No Need to Admit
# Patient 1009: Risk = 10.00% -> No Need to Admit
# Patient 1010: Risk = 15.00% -> No Need to Admit
# Patient 1011: Risk = 6.00% -> No Need to Admit
# Patient 1012: Risk = 7.00% -> No Need to Admit
# Patient 1013: Risk = 13.00% -> No Need to Admit
# Patient 1014: Risk = 18.00% -> No Need to Admit
# Patient 1015: Risk = 2.00% -> No Need to Admit
# Patient 1016: Risk = 4.00% -> No Need to Admit
# Patient 1017: Risk = 75.00% -> Admit
# Patient 1018: Risk = 5.00% -> No Need to Admit
# Patient 1019: Risk = 6.00% -> No Need to Admit
# Patient 1020: Risk = 7.00% -> No Need to Admit
# Patient 1021: Risk = 8.00% -> No Need to Admit
# Patient 1022: Risk = 3.00% -> No Need to Admit
# Patient 1023: Risk = 66.00% -> No Need to Admit
# Patient 1024: Risk = 10.00% -> No Need to Admit
# Patient 1025: Risk = 17.00% -> No Need to Admit
# Patient 1026: Risk = 1.00% -> No Need to Admit
# Patient 1027: Risk = 7.00% -> No Need to Admit
# Patient 1028: Risk = 75.00% -> Admit
# Patient 1029: Risk = 1.00% -> No Need to Admit
# Patient 1030: Risk = 4.00% -> No Need to Admit
# Patient 1031: Risk = 69.00% -> No Need to Admit
# Patient 1032: Risk = 3.00% -> No Need to Admit
# Patient 1033: Risk = 1.00% -> No Need to Admit
# Patient 1034: Risk = 67.00% -> No Need to Admit
# Patient 1035: Risk = 8.00% -> No Need to Admit
# Patient 1036: Risk = 10.00% -> No Need to Admit
# Patient 1037: Risk = 4.00% -> No Need to Admit
# Patient 1038: Risk = 2.00% -> No Need to Admit
# Patient 1039: Risk = 12.00% -> No Need to Admit
# Patient 1040: Risk = 10.00% -> No Need to Admit
# Patient 1041: Risk = 5.00% -> No Need to Admit
# Patient 1042: Risk = 4.00% -> No Need to Admit
# Patient 1043: Risk = 2.00% -> No Need to Admit
# Patient 1044: Risk = 6.00% -> No Need to Admit
# Patient 1045: Risk = 1.00% -> No Need to Admit
# Patient 1046: Risk = 7.00% -> No Need to Admit
# Patient 1047: Risk = 4.00% -> No Need to Admit
# Patient 1048: Risk = 2.00% -> No Need to Admit
# Patient 1049: Risk = 4.00% -> No Need to Admit
# Patient 1050: Risk = 2.00% -> No Need to Admit
# Patient 1051: Risk = 9.00% -> No Need to Admit
# Patient 1052: Risk = 10.00% -> No Need to Admit
# Patient 1053: Risk = 13.00% -> No Need to Admit
# Patient 1054: Risk = 69.00% -> No Need to Admit
# Patient 1055: Risk = 8.00% -> No Need to Admit
# Patient 1056: Risk = 1.00% -> No Need to Admit
# Patient 1057: Risk = 3.00% -> No Need to Admit
# Patient 1058: Risk = 7.00% -> No Need to Admit
# Patient 1059: Risk = 4.00% -> No Need to Admit
# ...
# Patient 4660: Risk = 11.00% -> No Need to Admit
# Patient 4661: Risk = 9.00% -> No Need to Admit
# Patient 4662: Risk = 6.00% -> No Need to Admit
# Patient 4663: Risk = 13.00% -> No Need to Admit
# Patient 4664: Risk = 4.00% -> No Need to Admit
# Patient 4665: Risk = 1.00% -> No Need to Admit
# Patient 4666: Risk = 4.00% -> No Need to Admit
# Patient 4667: Risk = 20.00% -> No Need to Admit
# Patient 4668: Risk = 1.00% -> No Need to Admit
# Patient 4669: Risk = 4.00% -> No Need to Admit
# Patient 4670: Risk = 65.00% -> No Need to Admit
# Patient 4671: Risk = 5.00% -> No Need to Admit
# Patient 4672: Risk = 20.00% -> No Need to Admit
# Patient 4673: Risk = 1.00% -> No Need to Admit
# Patient 4674: Risk = 4.00% -> No Need to Admit
# Patient 4675: Risk = 22.00% -> No Need to Admit
# Patient 4676: Risk = 22.00% -> No Need to Admit
# Patient 4677: Risk = 66.00% -> No Need to Admit
# Patient 4678: Risk = 5.00% -> No Need to Admit
# Patient 4679: Risk = 2.00% -> No Need to Admit
# Patient 4680: Risk = 5.00% -> No Need to Admit
# Patient 4681: Risk = 2.00% -> No Need to Admit
# Patient 4682: Risk = 4.00% -> No Need to Admit
# Patient 4683: Risk = 7.00% -> No Need to Admit
# Patient 4684: Risk = 78.00% -> Admit
# Patient 4685: Risk = 6.00% -> No Need to Admit
# Patient 4686: Risk = 1.00% -> No Need to Admit
# Patient 4687: Risk = 4.00% -> No Need to Admit
# Patient 4688: Risk = 70.00% -> No Need to Admit
# Patient 4689: Risk = 10.00% -> No Need to Admit
# Patient 4690: Risk = 68.00% -> No Need to Admit
# Patient 4691: Risk = 6.00% -> No Need to Admit
# Patient 4692: Risk = 5.00% -> No Need to Admit
# Patient 4693: Risk = 8.00% -> No Need to Admit
# Patient 4694: Risk = 64.00% -> No Need to Admit
# Patient 4695: Risk = 6.00% -> No Need to Admit
# Patient 4696: Risk = 12.00% -> No Need to Admit
# Patient 4697: Risk = 10.00% -> No Need to Admit
# Patient 4698: Risk = 10.00% -> No Need to Admit
# Patient 4699: Risk = 5.00% -> No Need to Admit
# Patient 4700: Risk = 80.00% -> Admit
# Patient 4701: Risk = 2.00% -> No Need to Admit
# Patient 4702: Risk = 2.00% -> No Need to Admit
# Patient 4703: Risk = 2.00% -> No Need to Admit
# Patient 4704: Risk = 1.00% -> No Need to Admit
# Patient 4705: Risk = 6.00% -> No Need to Admit
# Patient 4706: Risk = 71.00% -> Admit
# Patient 4707: Risk = 62.00% -> No Need to Admit
# Patient 4708: Risk = 4.00% -> No Need to Admit
# Patient 4709: Risk = 3.00% -> No Need to Admit
# Patient 4710: Risk = 15.00% -> No Need to Admit
# Patient 4711: Risk = 9.00% -> No Need to Admit
# Patient 4712: Risk = 76.00% -> Admit
# Patient 4713: Risk = 3.00% -> No Need to Admit
# Patient 4714: Risk = 3.00% -> No Need to Admit
# Patient 4715: Risk = 6.00% -> No Need to Admit
# Patient 4716: Risk = 0.00% -> No Need to Admit
# Patient 4717: Risk = 11.00% -> No Need to Admit
# Patient 4718: Risk = 69.00% -> No Need to Admit
# Patient 4719: Risk = 3.00% -> No Need to Admit
# Patient 4720: Risk = 72.00% -> Admit
# Patient 4721: Risk = 11.00% -> No Need to Admit
# Patient 4722: Risk = 6.00% -> No Need to Admit
# Patient 4723: Risk = 5.00% -> No Need to Admit
# Patient 4724: Risk = 3.00% -> No Need to Admit
# Patient 4725: Risk = 7.00% -> No Need to Admit
# Patient 4726: Risk = 1.00% -> No Need to Admit
# Patient 4727: Risk = 11.00% -> No Need to Admit
# Patient 4728: Risk = 10.00% -> No Need to Admit
# Patient 4729: Risk = 17.00% -> No Need to Admit
# Patient 4730: Risk = 6.00% -> No Need to Admit
# Patient 4731: Risk = 70.00% -> No Need to Admit
# Patient 4732: Risk = 69.00% -> No Need to Admit
# Patient 4733: Risk = 7.00% -> No Need to Admit
# Patient 4734: Risk = 1.00% -> No Need to Admit
# Patient 4735: Risk = 2.00% -> No Need to Admit
# Patient 4736: Risk = 8.00% -> No Need to Admit
# Patient 4737: Risk = 6.00% -> No Need to Admit
# Patient 4738: Risk = 6.00% -> No Need to Admit
# Patient 4739: Risk = 12.00% -> No Need to Admit
# Patient 4740: Risk = 7.00% -> No Need to Admit
# Patient 4741: Risk = 6.00% -> No Need to Admit
# Patient 4742: Risk = 10.00% -> No Need to Admit
# Patient 4743: Risk = 17.00% -> No Need to Admit
# Patient 4744: Risk = 7.00% -> No Need to Admit
# Patient 4745: Risk = 2.00% -> No Need to Admit
# Patient 4746: Risk = 8.00% -> No Need to Admit
# Patient 4747: Risk = 67.00% -> No Need to Admit
# Patient 4748: Risk = 9.00% -> No Need to Admit
# Patient 4749: Risk = 8.00% -> No Need to Admit
# Patient 4750: Risk = 4.00% -> No Need to Admit
# Patient 4751: Risk = 11.00% -> No Need to Admit
# Patient 4752: Risk = 8.00% -> No Need to Admit
# Patient 4753: Risk = 20.00% -> No Need to Admit
# Patient 4754: Risk = 13.00% -> No Need to Admit
# Patient 4755: Risk = 3.00% -> No Need to Admit
# Patient 4756: Risk = 2.00% -> No Need to Admit
# Patient 4757: Risk = 13.00% -> No Need to Admit
# Patient 4758: Risk = 8.00% -> No Need to Admit
# Patient 4759: Risk = 14.00% -> No Need to Admit
# Patient 4760: Risk = 10.00% -> No Need to Admit
# Patient 4761: Risk = 4.00% -> No Need to Admit
# Patient 4762: Risk = 13.00% -> No Need to Admit
# Patient 4763: Risk = 1.00% -> No Need to Admit
# Patient 4764: Risk = 66.00% -> No Need to Admit
# Patient 4765: Risk = 16.00% -> No Need to Admit
# Patient 4766: Risk = 7.00% -> No Need to Admit
# Patient 4767: Risk = 13.00% -> No Need to Admit
# Patient 4768: Risk = 4.00% -> No Need to Admit
# Patient 4769: Risk = 2.00% -> No Need to Admit
# Patient 4770: Risk = 1.00% -> No Need to Admit
# Patient 4771: Risk = 2.00% -> No Need to Admit
# Patient 4772: Risk = 4.00% -> No Need to Admit
# Patient 4773: Risk = 3.00% -> No Need to Admit
# Patient 4774: Risk = 68.00% -> No Need to Admit
# Patient 4775: Risk = 8.00% -> No Need to Admit
# Patient 4776: Risk = 10.00% -> No Need to Admit
# Patient 4777: Risk = 4.00% -> No Need to Admit
# Patient 4778: Risk = 9.33% -> No Need to Admit
# Patient 4779: Risk = 11.00% -> No Need to Admit
# Patient 4780: Risk = 68.00% -> No Need to Admit
# Patient 4781: Risk = 11.00% -> No Need to Admit
# Patient 4782: Risk = 3.00% -> No Need to Admit
# Patient 4783: Risk = 5.00% -> No Need to Admit
# Patient 4784: Risk = 11.00% -> No Need to Admit
# Patient 4785: Risk = 8.00% -> No Need to Admit
# Patient 4786: Risk = 2.00% -> No Need to Admit
# Patient 4787: Risk = 8.00% -> No Need to Admit
# Patient 4788: Risk = 67.00% -> No Need to Admit
# Patient 4789: Risk = 6.00% -> No Need to Admit
# Patient 4790: Risk = 69.00% -> No Need to Admit
# Patient 4791: Risk = 2.00% -> No Need to Admit
# Patient 4792: Risk = 4.00% -> No Need to Admit
# Patient 4793: Risk = 6.00% -> No Need to Admit
# Patient 4794: Risk = 4.00% -> No Need to Admit
# Patient 4795: Risk = 3.00% -> No Need to Admit
# Patient 4796: Risk = 7.00% -> No Need to Admit
# Patient 4797: Risk = 2.00% -> No Need to Admit
# Patient 4798: Risk = 6.00% -> No Need to Admit
# Patient 4799: Risk = 8.00% -> No Need to Admit
# Patient 4800: Risk = 67.00% -> No Need to Admit
# Patient 4801: Risk = 18.00% -> No Need to Admit
# Patient 4802: Risk = 9.00% -> No Need to Admit
# Patient 4803: Risk = 66.00% -> No Need to Admit
# Patient 4804: Risk = 5.00% -> No Need to Admit
# Patient 4805: Risk = 1.00% -> No Need to Admit
# Patient 4806: Risk = 10.00% -> No Need to Admit
# Patient 4807: Risk = 69.00% -> No Need to Admit
# Patient 4808: Risk = 11.00% -> No Need to Admit
# Patient 4809: Risk = 3.00% -> No Need to Admit
# Patient 4810: Risk = 19.00% -> No Need to Admit
# Patient 4811: Risk = 67.00% -> No Need to Admit
# Patient 4812: Risk = 64.00% -> No Need to Admit
# Patient 4813: Risk = 13.00% -> No Need to Admit
# Patient 4814: Risk = 72.00% -> Admit
# Patient 4815: Risk = 3.00% -> No Need to Admit
# Patient 4816: Risk = 13.00% -> No Need to Admit
# Patient 4817: Risk = 68.00% -> No Need to Admit
# Patient 4818: Risk = 7.00% -> No Need to Admit
# Patient 4819: Risk = 4.00% -> No Need to Admit
# Patient 4820: Risk = 6.00% -> No Need to Admit
# Patient 4821: Risk = 2.00% -> No Need to Admit
# Patient 4822: Risk = 64.00% -> No Need to Admit
# Patient 4823: Risk = 75.00% -> Admit
# Patient 4824: Risk = 8.00% -> No Need to Admit
# Patient 4825: Risk = 65.00% -> No Need to Admit
# Patient 4826: Risk = 4.00% -> No Need to Admit
# Patient 4827: Risk = 11.00% -> No Need to Admit
# Patient 4828: Risk = 6.00% -> No Need to Admit
# Patient 4829: Risk = 11.00% -> No Need to Admit
# Patient 4830: Risk = 7.00% -> No Need to Admit
# Patient 4831: Risk = 9.00% -> No Need to Admit
# Patient 4832: Risk = 6.00% -> No Need to Admit
# Patient 4833: Risk = 7.00% -> No Need to Admit
# Patient 4834: Risk = 10.00% -> No Need to Admit
# Patient 4835: Risk = 6.00% -> No Need to Admit
# Patient 4836: Risk = 7.00% -> No Need to Admit
# Patient 4837: Risk = 8.00% -> No Need to Admit
# Patient 4838: Risk = 12.00% -> No Need to Admit
# Patient 4839: Risk = 3.00% -> No Need to Admit
# Patient 4840: Risk = 2.00% -> No Need to Admit
# Patient 4841: Risk = 63.00% -> No Need to Admit
# Patient 4842: Risk = 6.00% -> No Need to Admit
# Patient 4843: Risk = 5.00% -> No Need to Admit
# Patient 4844: Risk = 76.00% -> Admit
# Patient 4845: Risk = 7.00% -> No Need to Admit
# Patient 4846: Risk = 65.00% -> No Need to Admit
# Patient 4847: Risk = 8.00% -> No Need to Admit
# Patient 4848: Risk = 3.00% -> No Need to Admit
# Patient 4849: Risk = 10.00% -> No Need to Admit
# Patient 4850: Risk = 19.00% -> No Need to Admit
# Patient 4851: Risk = 65.00% -> No Need to Admit
# Patient 4852: Risk = 73.00% -> Admit
# Patient 4853: Risk = 72.00% -> Admit
# Patient 4854: Risk = 67.00% -> No Need to Admit
# Patient 4855: Risk = 73.00% -> Admit
# Patient 4856: Risk = 6.00% -> No Need to Admit
# Patient 4857: Risk = 82.00% -> Admit
# Patient 4858: Risk = 9.00% -> No Need to Admit
# Patient 4859: Risk = 15.00% -> No Need to Admit
# Patient 4860: Risk = 1.00% -> No Need to Admit
# Patient 4861: Risk = 75.00% -> Admit
# Patient 4862: Risk = 6.00% -> No Need to Admit
# Patient 4863: Risk = 69.00% -> No Need to Admit
# Patient 4864: Risk = 3.00% -> No Need to Admit
# Patient 4865: Risk = 8.00% -> No Need to Admit
# Patient 4866: Risk = 75.00% -> Admit
# Patient 4867: Risk = 5.00% -> No Need to Admit
# Patient 4868: Risk = 69.00% -> No Need to Admit
# Patient 4869: Risk = 8.00% -> No Need to Admit
# Patient 4870: Risk = 8.00% -> No Need to Admit
# Patient 4871: Risk = 61.00% -> No Need to Admit
# Patient 4872: Risk = 11.00% -> No Need to Admit
# Patient 4873: Risk = 6.00% -> No Need to Admit
# Patient 4874: Risk = 14.00% -> No Need to Admit
# Patient 4875: Risk = 10.00% -> No Need to Admit
# Patient 4876: Risk = 12.00% -> No Need to Admit
# Patient 4877: Risk = 4.00% -> No Need to Admit
# Patient 4878: Risk = 72.00% -> Admit
# Patient 4879: Risk = 10.00% -> No Need to Admit
# Patient 4880: Risk = 4.00% -> No Need to Admit
# Patient 4881: Risk = 72.00% -> Admit
# Patient 4882: Risk = 65.00% -> No Need to Admit
# Patient 4883: Risk = 10.00% -> No Need to Admit
# Patient 4884: Risk = 3.00% -> No Need to Admit
# Patient 4885: Risk = 2.00% -> No Need to Admit
# Patient 4886: Risk = 0.00% -> No Need to Admit
# Patient 4887: Risk = 4.00% -> No Need to Admit
# Patient 4888: Risk = 1.00% -> No Need to Admit
# Patient 4889: Risk = 4.00% -> No Need to Admit
# Patient 4890: Risk = 13.00% -> No Need to Admit
# Patient 4891: Risk = 11.00% -> No Need to Admit
# Patient 4892: Risk = 13.00% -> No Need to Admit
# Patient 4893: Risk = 10.00% -> No Need to Admit
# Patient 4894: Risk = 66.00% -> No Need to Admit
# Patient 4895: Risk = 2.00% -> No Need to Admit
# Patient 4896: Risk = 2.00% -> No Need to Admit
# Patient 4897: Risk = 7.00% -> No Need to Admit
# Patient 4898: Risk = 21.00% -> No Need to Admit
# Patient 4899: Risk = 14.00% -> No Need to Admit
# Patient 4900: Risk = 10.00% -> No Need to Admit
# Patient 4901: Risk = 7.00% -> No Need to Admit
# Patient 4902: Risk = 59.00% -> No Need to Admit
# Patient 4903: Risk = 6.92% -> No Need to Admit
# Patient 4904: Risk = 3.00% -> No Need to Admit
# Patient 4905: Risk = 1.00% -> No Need to Admit
# Patient 4906: Risk = 15.00% -> No Need to Admit
# Patient 4907: Risk = 6.00% -> No Need to Admit
# Patient 4908: Risk = 7.00% -> No Need to Admit
# Patient 4909: Risk = 5.00% -> No Need to Admit
# Patient 4910: Risk = 11.00% -> No Need to Admit
# Patient 4911: Risk = 7.00% -> No Need to Admit
# Patient 4912: Risk = 9.00% -> No Need to Admit
# Patient 4913: Risk = 5.00% -> No Need to Admit
# Patient 4914: Risk = 71.00% -> Admit
# Patient 4915: Risk = 10.00% -> No Need to Admit
# Patient 4916: Risk = 10.00% -> No Need to Admit
# Patient 4917: Risk = 71.00% -> Admit
# Patient 4918: Risk = 6.00% -> No Need to Admit
# Patient 4919: Risk = 12.00% -> No Need to Admit
# Patient 4920: Risk = 4.00% -> No Need to Admit
# Patient 4921: Risk = 5.00% -> No Need to Admit
# Patient 4922: Risk = 73.00% -> Admit
# Patient 4923: Risk = 9.00% -> No Need to Admit
# Patient 4924: Risk = 3.00% -> No Need to Admit
# Patient 4925: Risk = 4.00% -> No Need to Admit
# Patient 4926: Risk = 2.00% -> No Need to Admit
# Patient 4927: Risk = 3.00% -> No Need to Admit
# Patient 4928: Risk = 3.00% -> No Need to Admit
# Patient 4929: Risk = 7.00% -> No Need to Admit
# Patient 4930: Risk = 10.00% -> No Need to Admit
# Patient 4931: Risk = 7.00% -> No Need to Admit
# Patient 4932: Risk = 61.00% -> No Need to Admit
# Patient 4933: Risk = 63.00% -> No Need to Admit
# Patient 4934: Risk = 59.00% -> No Need to Admit
# Patient 4935: Risk = 8.00% -> No Need to Admit
# Patient 4936: Risk = 2.00% -> No Need to Admit
# Patient 4937: Risk = 11.00% -> No Need to Admit
# Patient 4938: Risk = 7.00% -> No Need to Admit
# Patient 4939: Risk = 0.00% -> No Need to Admit
# Patient 4940: Risk = 12.00% -> No Need to Admit
# Patient 4941: Risk = 12.00% -> No Need to Admit
# Patient 4942: Risk = 7.00% -> No Need to Admit
# Patient 4943: Risk = 6.00% -> No Need to Admit
# Patient 4944: Risk = 11.00% -> No Need to Admit
# Patient 4945: Risk = 7.00% -> No Need to Admit
# Patient 4946: Risk = 8.00% -> No Need to Admit
# Patient 4947: Risk = 14.00% -> No Need to Admit
# Patient 4948: Risk = 3.00% -> No Need to Admit
# Patient 4949: Risk = 2.00% -> No Need to Admit
# Patient 4950: Risk = 6.00% -> No Need to Admit
# Patient 4951: Risk = 14.00% -> No Need to Admit
# Patient 4952: Risk = 10.00% -> No Need to Admit
# Patient 4953: Risk = 10.00% -> No Need to Admit
# Patient 4954: Risk = 65.00% -> No Need to Admit
# Patient 4955: Risk = 6.00% -> No Need to Admit
# Patient 4956: Risk = 3.00% -> No Need to Admit
# Patient 4957: Risk = 17.00% -> No Need to Admit
# Patient 4958: Risk = 13.00% -> No Need to Admit
# Patient 4959: Risk = 15.00% -> No Need to Admit
# Patient 4960: Risk = 2.00% -> No Need to Admit
# Patient 4961: Risk = 20.00% -> No Need to Admit
# Patient 4962: Risk = 7.00% -> No Need to Admit
# Patient 4963: Risk = 4.00% -> No Need to Admit
# Patient 4964: Risk = 4.00% -> No Need to Admit
# Patient 4965: Risk = 9.00% -> No Need to Admit
# Patient 4966: Risk = 70.00% -> No Need to Admit
# Patient 4967: Risk = 8.00% -> No Need to Admit
# Patient 4968: Risk = 8.00% -> No Need to Admit
# Patient 4969: Risk = 13.00% -> No Need to Admit
# Patient 4970: Risk = 10.00% -> No Need to Admit
# Patient 4971: Risk = 8.00% -> No Need to Admit
# Patient 4972: Risk = 70.00% -> No Need to Admit
# Patient 4973: Risk = 5.00% -> No Need to Admit
# Patient 4974: Risk = 17.00% -> No Need to Admit
# Patient 4975: Risk = 69.00% -> No Need to Admit
# Patient 4976: Risk = 68.00% -> No Need to Admit
# Patient 4977: Risk = 11.00% -> No Need to Admit
# Patient 4978: Risk = 6.00% -> No Need to Admit
# Patient 4979: Risk = 16.00% -> No Need to Admit
# Patient 4980: Risk = 2.00% -> No Need to Admit
# Patient 4981: Risk = 73.00% -> Admit
# Patient 4982: Risk = 2.00% -> No Need to Admit
# Patient 4983: Risk = 9.00% -> No Need to Admit
# Patient 4984: Risk = 7.00% -> No Need to Admit
# Patient 4985: Risk = 15.00% -> No Need to Admit
# Patient 4986: Risk = 7.00% -> No Need to Admit
# Patient 4987: Risk = 67.00% -> No Need to Admit
# Patient 4988: Risk = 16.00% -> No Need to Admit
# Patient 4989: Risk = 5.00% -> No Need to Admit
# Patient 4990: Risk = 5.00% -> No Need to Admit
# Patient 4991: Risk = 6.00% -> No Need to Admit
# Patient 4992: Risk = 7.00% -> No Need to Admit
# Patient 4993: Risk = 8.00% -> No Need to Admit
# Patient 4994: Risk = 6.00% -> No Need to Admit
# Patient 4995: Risk = 11.00% -> No Need to Admit
# Patient 4996: Risk = 9.00% -> No Need to Admit
# Patient 4997: Risk = 1.00% -> No Need to Admit
# Patient 4998: Risk = 16.00% -> No Need to Admit
# Patient 4999: Risk = 8.00% -> No Need to Admit
# Patient 5000: Risk = 10.00% -> No Need to Admit

# %%
import pickle




# Save the trained model to a file
with open("model.pkl", "wb") as f:
    pickle.dump(model, f)
print("Model saved successfully!")
# Out:
# Model saved successfully!
